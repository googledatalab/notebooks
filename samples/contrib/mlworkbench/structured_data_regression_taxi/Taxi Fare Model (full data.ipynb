# %% [markdown]
# # About This Notebook
#
# This notebook demonstrate how to use ML Workbench to create a regression model that accepts numeric and categorical data. This one shows "cloud run" mode, which does each step in Google Cloud Platform with various services. Cloud run can be distributed so it can handle large data without being restricted on memory, computation, or disk limits. The notebook is similar to last one (Taxi Fare Model (small data)), but it uses full data (about 77M instances).
#
# There are only a few things that need to change between "local run" and "cloud run":
#
# * all data sources or file paths must be on GCS.
# * the --cloud flag must be set for each step.
# * "cloud_config" can be set for cloud specific settings, such as project_id, machine_type. In some cases it is required.
#
# Other than this, nothing else changes from local to cloud!
#
# Note: "Run all cells" does not work for this notebook because the steps are asynchonous. In many steps it submits a cloud job, and you should track the status by following the job link.
#
# Execution of this notebook requires Google Datalab (see [setup instructions](https://cloud.google.com/datalab/docs/quickstarts)).

# %% [markdown]
# # The Data
#
# We will use [Chicago Taxi Trip Data](https://cloud.google.com/bigquery/public-data/chicago-taxi). Using pickup location, drop off location, taxi company, the model we will build predicts the trip fare.

# %% [markdown]
# ## Split Data Into Train/Eval Sets
#
# Use bigquery to select the features we need and also randomly choose 5% for eval, 95% for training.

# %%
# %%bq query --name texi_query_eval
# SELECT
#   unique_key,
#   fare,
#   CAST(EXTRACT(DAYOFWEEK FROM trip_start_timestamp) AS STRING) as weekday,
#   CAST(EXTRACT(DAYOFYEAR FROM trip_start_timestamp) AS STRING) as day,
#   CAST(EXTRACT(HOUR FROM trip_start_timestamp) AS STRING) as hour,
#   taxi_id,
#   pickup_latitude,
#   pickup_longitude,
#   dropoff_latitude,
#   dropoff_longitude,
#   company
# FROM `bigquery-public-data.chicago_taxi_trips.taxi_trips`
# WHERE
#   fare > 2.0 AND fare < 200.0 AND
#   pickup_latitude IS NOT NULL AND
#   pickup_longitude IS NOT NULL AND
#   dropoff_latitude IS NOT NULL AND
#   dropoff_longitude IS NOT NULL AND
#   taxi_id IS NOT NULL AND
#   MOD(ABS(FARM_FINGERPRINT(unique_key)), 100) < 5

# %%
# %%bq query --name texi_query_train
# SELECT
#   unique_key,
#   fare,
#   CAST(EXTRACT(DAYOFWEEK FROM trip_start_timestamp) AS STRING) as weekday,
#   CAST(EXTRACT(DAYOFYEAR FROM trip_start_timestamp) AS STRING) as day,
#   CAST(EXTRACT(HOUR FROM trip_start_timestamp) AS STRING) as hour,
#   taxi_id,
#   pickup_latitude,
#   pickup_longitude,
#   dropoff_latitude,
#   dropoff_longitude,
#   company
# FROM `bigquery-public-data.chicago_taxi_trips.taxi_trips`
# WHERE
#   fare > 2.0 AND fare < 200.0 AND
#   pickup_latitude IS NOT NULL AND
#   pickup_longitude IS NOT NULL AND
#   dropoff_latitude IS NOT NULL AND
#   dropoff_longitude IS NOT NULL AND
#   taxi_id IS NOT NULL AND
#   MOD(ABS(FARM_FINGERPRINT(unique_key)), 100) >= 5

# %% [markdown]
# Create "chicago_taxi.train" and "chicago_taxi.eval" BQ tables to store results.

# %%
# %%bq datasets create --name chicago_taxi

# %%
# %%bq execute
# query: texi_query_eval
# table: chicago_taxi.eval
# mode: overwrite

# %%
# %%bq execute
# query: texi_query_train
# table: chicago_taxi.train
# mode: overwrite

# %%
# !gsutil rm -r -f gs://datalab-chicago-taxi/analysis
# Out:
# Removing gs://datalab-chicago-taxi/analysis/tmp/features.json#1504802108571901...
# Removing gs://datalab-chicago-taxi/analysis/vocab_company.csv#1504802122475741...
# Removing gs://datalab-chicago-taxi/analysis/vocab_hour.csv#1504802119124248...
# / [3 objects]
# Operation completed over 3 objects.

# %% [markdown]
# Sanity check on the data.

# %%
# %%bq query
# SELECT * FROM chicago_taxi.train LIMIT 5
# Out:
# QueryResultsTable job_pU2FqtuI7quu-yJAvVDp7po7zxsQ

# %%
# %%bq query
# SELECT count(*) FROM chicago_taxi.train
# Out:
# QueryResultsTable job_haGLqfX0TUkTG57cSwgpjmTNE2Pr

# %%
# %%bq query
# SELECT count(*) FROM chicago_taxi.eval
# Out:
# QueryResultsTable job_cUiLuBZ-CIBk48cba6MtDcndNpE-

# %% [markdown]
# ## Explore Data
#
# See previous notebook (Taxi Fare Model (small data)) for data exploration.

# %% [markdown]
# # Create Model with ML Workbench
#
#
# The MLWorkbench Magics are a set of Datalab commands that allow an easy code-free experience to training, deploying, and predicting ML models. This notebook will take the data in BigQuery tables and build a regression model. The MLWorkbench Magics are a collection of magic commands for each step in ML workflows: analyzing input data to build transforms, transforming data, training a model, evaluating a model, and deploying a model.
#
# For details of each command, run with --help. For example, "%%ml train --help".
#
# This notebook will run the analyze, transform, and training steps in cloud with services. Notice the "--cloud" flag is set for each step.

# %%
import google.datalab.contrib.mlworkbench.commands # this loads the %%ml commands

# %%
# !gsutil mb gs://datalab-chicago-taxi # Create a Storage Bucket to store results.

# %% [markdown]
# ## Step 1: Analyze
#
# The first step in the MLWorkbench workflow is to analyze the data for the requested transformations. Analysis in this case builds vocabulary for categorical features, and compute numeric stats for numeric features.

# %%
# !gsutil rm -r -f gs://datalab-chicago-taxi/analysis # Remove previous analysis results.

# %%
# %%ml analyze --cloud
# output: gs://datalab-chicago-taxi/analysis
# training_data:
#   bigquery_table: chicago_taxi.train
# features:
#   unique_key:
#     transform: key
#   fare:
#     transform: target
#   taxi_id:
#     transform: embedding
#     embedding_dim: 50
#   company:
#     transform: embedding
#     embedding_dim: 10
#   weekday:
#     transform: one_hot
#   day:
#     transform: one_hot
#   hour:
#     transform: one_hot
#   pickup_latitude:
#     transform: scale
#   pickup_longitude:
#     transform: scale
#   dropoff_latitude:
#     transform: scale
#   dropoff_longitude:
#     transform: scale
# Out:
# Analyzing column fare...
# Updated property [core/project].
# column fare analyzed.
# Analyzing column hour...
# Updated property [core/project].
# column hour analyzed.
# Analyzing column company...
# Updated property [core/project].
# column company analyzed.
# Analyzing column pickup_longitude...
# Updated property [core/project].
# column pickup_longitude analyzed.
# Analyzing column day...
# Updated property [core/project].
# column day analyzed.
# Analyzing column dropoff_longitude...
# Updated property [core/project].
# column dropoff_longitude analyzed.
# Analyzing column taxi_id...
# Updated property [core/project].
# column taxi_id analyzed.
# Analyzing column weekday...
# Updated property [core/project].
# column weekday analyzed.
# Analyzing column pickup_latitude...
# Updated property [core/project].
# column pickup_latitude analyzed.
# Analyzing column dropoff_latitude...
# Updated property [core/project].
# column dropoff_latitude analyzed.
# Updated property [core/project].

# %% [markdown]
# ## Step 2: Transform
#
# The transform step performs some transformations on the input data and saves the results to a special TensorFlow file called a TFRecord file containing TF.Example protocol buffers. This allows training to start from preprocessed data. If this step is not used, training would have to perform the same preprocessing on every row of csv data every time it is used. As TensorFlow reads the same data row multiple times during training, this means the same row would be preprocessed multiple times. By writing the preprocessed data to disk, we can speed up training.
#
# The transform is required if your source data is in BigQuery table.
#
# We run the transform step for the training and eval data.

# %%
# !gsutil rm -r -f gs://datalab-chicago-taxi/transform # Remove previous transform results.

# %% [markdown]
# Transform takes about 6 hours in cloud. Data is fairely big (33GB) and processing locally on a single VM would be much longer.

# %%
# %%ml transform --cloud
# output: gs://datalab-chicago-taxi/transform
# analysis: gs://datalab-chicago-taxi/analysis
# prefix: train
# training_data:
#   bigquery_table: chicago_taxi.train
# Out:
# /usr/local/lib/python2.7/dist-packages/apache_beam/coders/typecoders.py:135: UserWarning: Using fallback coder for typehint: Any.
#   warnings.warn('Using fallback coder for typehint: %r.' % typehint)
# running sdist
# running egg_info
# creating trainer.egg-info
# writing requirements to trainer.egg-info/requires.txt
# writing trainer.egg-info/PKG-INFO
# writing top-level names to trainer.egg-info/top_level.txt
# writing dependency_links to trainer.egg-info/dependency_links.txt
# writing manifest file 'trainer.egg-info/SOURCES.txt'
# reading manifest file 'trainer.egg-info/SOURCES.txt'
# writing manifest file 'trainer.egg-info/SOURCES.txt'
# warning: sdist: standard file not found: should have one of README, README.rst, README.txt
#
# running check
# warning: check: missing required meta-data: url
#
# creating trainer-1.0.0
# creating trainer-1.0.0/trainer
# creating trainer-1.0.0/trainer.egg-info
# making hard links in trainer-1.0.0...
# hard linking setup.py -> trainer-1.0.0
# hard linking trainer/__init__.py -> trainer-1.0.0/trainer
# hard linking trainer/feature_transforms.py -> trainer-1.0.0/trainer
# hard linking trainer/task.py -> trainer-1.0.0/trainer
# hard linking trainer.egg-info/PKG-INFO -> trainer-1.0.0/trainer.egg-info
# hard linking trainer.egg-info/SOURCES.txt -> trainer-1.0.0/trainer.egg-info
# hard linking trainer.egg-info/dependency_links.txt -> trainer-1.0.0/trainer.egg-info
# hard linking trainer.egg-info/requires.txt -> trainer-1.0.0/trainer.egg-info
# hard linking trainer.egg-info/top_level.txt -> trainer-1.0.0/trainer.egg-info
# Writing trainer-1.0.0/setup.cfg
# Creating tar archive
# removing 'trainer-1.0.0' (and everything under it)
# DEPRECATION: pip install --download has been deprecated and will be removed in the future. Pip now has a download command that should be used instead.
# Collecting google-cloud-dataflow==2.0.0
#   Downloading google-cloud-dataflow-2.0.0.tar.gz (576kB)
#   Saved /tmp/tmpeLv9vH/google-cloud-dataflow-2.0.0.tar.gz
# Successfully downloaded google-cloud-dataflow
# /usr/local/lib/python2.7/dist-packages/apache_beam/io/gcp/gcsio.py:113: DeprecationWarning: object() takes no parameters
#   super(GcsIO, cls).__new__(cls, storage_client))
# View job at https://console.developers.google.com/dataflow/job/2017-09-07_09_47_19-2750090342691496354?project=bradley-playground

# %%
# %%ml transform --cloud
# output: gs://datalab-chicago-taxi/transform
# analysis: gs://datalab-chicago-taxi/analysis
# prefix: eval
# training_data:
#   bigquery_table: chicago_taxi.eval
# Out:
# /usr/local/lib/python2.7/dist-packages/apache_beam/coders/typecoders.py:135: UserWarning: Using fallback coder for typehint: Any.
#   warnings.warn('Using fallback coder for typehint: %r.' % typehint)
# running sdist
# running egg_info
# writing requirements to trainer.egg-info/requires.txt
# writing trainer.egg-info/PKG-INFO
# writing top-level names to trainer.egg-info/top_level.txt
# writing dependency_links to trainer.egg-info/dependency_links.txt
# reading manifest file 'trainer.egg-info/SOURCES.txt'
# writing manifest file 'trainer.egg-info/SOURCES.txt'
# warning: sdist: standard file not found: should have one of README, README.rst, README.txt
#
# running check
# warning: check: missing required meta-data: url
#
# creating trainer-1.0.0
# creating trainer-1.0.0/trainer
# creating trainer-1.0.0/trainer.egg-info
# making hard links in trainer-1.0.0...
# hard linking setup.py -> trainer-1.0.0
# hard linking trainer/__init__.py -> trainer-1.0.0/trainer
# hard linking trainer/feature_transforms.py -> trainer-1.0.0/trainer
# hard linking trainer/task.py -> trainer-1.0.0/trainer
# hard linking trainer.egg-info/PKG-INFO -> trainer-1.0.0/trainer.egg-info
# hard linking trainer.egg-info/SOURCES.txt -> trainer-1.0.0/trainer.egg-info
# hard linking trainer.egg-info/dependency_links.txt -> trainer-1.0.0/trainer.egg-info
# hard linking trainer.egg-info/requires.txt -> trainer-1.0.0/trainer.egg-info
# hard linking trainer.egg-info/top_level.txt -> trainer-1.0.0/trainer.egg-info
# Writing trainer-1.0.0/setup.cfg
# Creating tar archive
# removing 'trainer-1.0.0' (and everything under it)
# DEPRECATION: pip install --download has been deprecated and will be removed in the future. Pip now has a download command that should be used instead.
# Collecting google-cloud-dataflow==2.0.0
#   Using cached google-cloud-dataflow-2.0.0.tar.gz
#   Saved /tmp/tmpzdjh8Y/google-cloud-dataflow-2.0.0.tar.gz
# Successfully downloaded google-cloud-dataflow
# /usr/local/lib/python2.7/dist-packages/apache_beam/io/gcp/gcsio.py:113: DeprecationWarning: object() takes no parameters
#   super(GcsIO, cls).__new__(cls, storage_client))
# View job at https://console.developers.google.com/dataflow/job/2017-09-07_09_47_46-4644060266734123379?project=bradley-playground

# %%
# !gsutil list gs://datalab-chicago-taxi/transform

# %% [markdown]
# ## Step 3: Training
#
# MLWorkbench help build standard TensorFlow models without you having to write any TensorFlow code. We already know from last notebook that DNN regression model works better.

# %%
# !gsutil rm -r -f gs://datalab-chicago-taxi/train # Remove previous training results.

# %% [markdown]
# Training takes about 40 min with "STANRDARD_1" scale_tier.

# %%
# %%ml train --cloud
# output: gs://datalab-chicago-taxi/train
# analysis: gs://datalab-chicago-taxi/analysis
# training_data:
#     transformed: gs://datalab-chicago-taxi/transform/train-*
# evaluation_data:
#     transformed: gs://datalab-chicago-taxi/transform/eval-*
# model_args:
#     model: dnn_regression
#     max-steps: 200000
#     save-checkpoints-secs: 300
#     hidden-layer-size1: 400
#     hidden-layer-size2: 200
#     train-batch-size: 1000
#     eval-batch-size: 1000
#     learning-rate: 0.001
# cloud_config:
#     region: us-east1
#     scale_tier: STANDARD_1
# Out:
# Job "trainer_task_170907_223009" submitted.<p>Click <a href="https://console.developers.google.com/logs/viewer?project=bradley-playground&resource=ml.googleapis.com%2Fjob_id%2Ftrainer_task_170907_223009" target="_blank">here</a> to view cloud log. <br/>

# %% [markdown]
# From the log, we have:
#
# ...
# Saving dict for global step 200008: global_step = 200008, loss = 11.557
# Finished evaluation at 2017-09-07-23:08:50
# ...

# %% [markdown]
# Note that Tensorboard works too for training in Cloud Storage.

# %%
from google.datalab.ml import TensorBoard

TensorBoard().start('gs://datalab-chicago-taxi/train')
# Out:
# <p>TensorBoard was started successfully with pid 2585. Click <a href="/_proxy/59894/" target="_blank">here</a> to access it.</p>
# 2585

# %% [markdown]
# Plot the loss summary. It takes a while because we have more events and it needs to download events from GCS.

# %%
from google.datalab.ml import Summary

summary = Summary('gs://datalab-chicago-taxi/train')
summary.plot('loss')

# %% [markdown]
# ## Step 4: Evaluation using batch prediction
#
# Below, we use the evaluation model and run batch prediction in cloud. For demo purpose, we will use the evaluation data again.

# %%
# !rm -r -f ./taxi/batch_predict # Remove previous batch prediction results.

# %% [markdown]
# Currently, batch_prediction service does not work with BigQuery data. So we export eval data to csv file.

# %%
# %%bq extract
# table: chicago_taxi.eval
# format: csv
# path: gs://datalab-chicago-taxi/eval.csv
# Out:
# Job bradley-playground/job_83_A9-weJOgbRzXAZytR29-YfmzR completed

# %% [markdown]
# Run batch prediction. Note that we use evaluation_model because it takes input data with target (truth) column.

# %%
# %%ml batch_predict --cloud
# model: gs://datalab-chicago-taxi/train/evaluation_model
# output: gs://datalab-chicago-taxi/batch_prediction
# format: csv
# prediction_data:
#   csv: gs://datalab-chicago-taxi/eval.csv
# cloud_config:
#   region: us-east1
# Out:
# Job "prediction_170908_001217" submitted.<p>Click <a href="https://console.developers.google.com/logs/viewer?project=bradley-playground&resource=ml.googleapis.com%2Fjob_id%2Fprediction_170908_001217" target="_blank">here</a> to view cloud log. <br/>

# %% [markdown]
# Once batch prediction is done, check results files. Batch prediction service outputs to JSON files.

# %%
# !gsutil list -l -h gs://datalab-chicago-taxi/batch_prediction
# Out:
#       38 B  2017-09-08T00:22:43Z  gs://datalab-chicago-taxi/batch_prediction/prediction.errors_stats-00000-of-00001
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00000-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00001-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00002-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00003-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00004-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00005-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00006-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00007-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00008-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00009-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00010-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00011-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00012-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00013-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00014-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00015-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00016-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00017-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00018-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00019-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00020-of-00045
#   2.67 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00021-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00022-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00023-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00024-of-00045
#   9.72 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00025-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00026-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00027-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00028-of-00045
#   9.17 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00029-of-00045
#   9.74 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00030-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00031-of-00045
#   9.74 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00032-of-00045
#   9.74 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00033-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00034-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00035-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00036-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00037-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00038-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00039-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00040-of-00045
#   7.06 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00041-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00042-of-00045
#   9.74 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00043-of-00045
#   9.73 MiB  2017-09-08T00:22:42Z  gs://datalab-chicago-taxi/batch_prediction/prediction.results-00044-of-00045
# TOTAL: 46 objects, 448457951 bytes (427.68 MiB)

# %% [markdown]
# We can load the results back to BigQuery.

# %%
# %%bq load
# format: json
# mode: overwrite
# table: chicago_taxi.eval_results
# path: gs://datalab-chicago-taxi/batch_prediction/prediction.results*
# schema:
#   - name: unique_key
#     type: STRING
#   - name: predicted
#     type: FLOAT
#   - name: target
#     type: FLOAT

# %% [markdown]
# With data in BigQuery can do some query analysis. For example, RMSE.

# %%
# %%bq query
# SELECT
#   SQRT(SUM(ABS(predicted-target) * ABS(predicted-target)) / COUNT(*))
# FROM
#   `chicago_taxi.eval_results`
# Out:
# QueryResultsTable job_V05LjMUJDb9lOP9dkvIbzYvOv2Q8

# %% [markdown]
# Select top results sorted by error.

# %%
# %%bq query
# SELECT
#   predicted,
#   target,
#   ABS(predicted-target) as error,
#   s.*
# FROM `chicago_taxi.eval_results` as r
# JOIN `chicago_taxi.eval` as s
# ON r.unique_key = s.unique_key
# ORDER BY error DESC
# LIMIT 10
# Out:
# QueryResultsTable job__wVpLpoG2I2jLR0FFqmITUUIFEBl

# %% [markdown]
# There is also a feature slice visualization component designed for viewing evaluation results. It shows correlation between features and prediction results.

# %%
# %%bq query --name error_by_hour
# SELECT
#   COUNT(*) as count,
#   hour as feature,
#   AVG(ABS(predicted - target)) as avg_error,
#   STDDEV(ABS(predicted - target)) as stddev_error
# FROM `chicago_taxi.eval_results` as r
# JOIN `chicago_taxi.eval` as s
# ON r.unique_key = s.unique_key
# GROUP BY hour

# %%
# Note: the interactive output is replaced with a static image so it displays well in github.
# Please execute this cell to see the interactive component.

from google.datalab.ml import FeatureSliceView

FeatureSliceView().plot(error_by_hour)

# %%
# %%bq query --name error_by_weekday
# SELECT
#   COUNT(*) as count,
#   weekday as feature,
#   AVG(ABS(predicted - target)) as avg_error,
#   STDDEV(ABS(predicted - target)) as stddev_error
# FROM `chicago_taxi.eval_results` as r
# JOIN `chicago_taxi.eval` as s
# ON r.unique_key = s.unique_key
# GROUP BY weekday

# %%
# Note: the interactive output is replaced with a static image so it displays well in github.
# Please execute this cell to see the interactive component.

from google.datalab.ml import FeatureSliceView

FeatureSliceView().plot(error_by_weekday)

# %% [markdown]
# What we can see from above charts is that model performs worst in hour 5 and 6 (why?), and best on Sundays (less traffic?).

# %% [markdown]
# # Model Deployment and Online Prediction
#
# Model deployment works the same between locally trained models and cloud trained models. Please see previous notebook (Taxi Fare Model (small data)).
