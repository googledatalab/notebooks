# %% [markdown]
# ## Feature Exploration
# This notebook demos how to use %%mlalpha features to generate featureset class, and how to use datalab.ml.DataSet to analyze and visualize your data.
#
# Analysis of the feature data will provide insights of data, such that: <br>
#
# 1. Find correlations of features so you know which features should be included in training. This is especially useful in linear models.
# 2. Spot outliers of data and evaluate the data quality. Important if you have data from different sources with unknown accuracy.
# 3. Decide how to preprocess the data. Based on the value distribution, you may decide instead of identity(), use scaling, log, or bucketized transformation.

# %% [markdown]
# ### Prepare Data
#
# Download training and eval files to local disk. The iris data is tiny, so we can explore the data locally without sampling.

# %%
# !mkdir -p /content/datalab/ml/iris
# !gsutil cp gs://cloud-datalab/sampledata/ml/iris/data_train.csv /content/datalab/tmp/ml/iris/data_train.csv
# !gsutil cp gs://cloud-datalab/sampledata/ml/iris/data_eval.csv /content/datalab/tmp/ml/iris/data_eval.csv
# Out:
# Copying gs://cloud-datalab/sampledata/ml/iris/data_train.csv...
# / [1 files][  3.8 KiB/  3.8 KiB]
# Operation completed over 1 objects/3.8 KiB.
# Copying gs://cloud-datalab/sampledata/ml/iris/data_eval.csv...
# / [1 files][  974.0 B/  974.0 B]
# Operation completed over 1 objects/974.0 B.

# %% [markdown]
# ### Define Dataset
# If you don't know how to start with, just run "%ml features" and it will generate the cell template for you to fill out.

# %%
# %%mlalpha features

# %% [markdown]
# You will see output like:<br><br>
# %%mlalpha features<br>
# path: REQUIRED_Fill_In_Gcs_or_Local_Path<br>
# headers: List_Of_Column_Names_Seperated_By_Comma<br>
# target: REQUIRED_Fill_In_Name_Or_Index_Of_Target_Column<br>
# id: Fill_In_Name_Or_Index_Of_Id_Column<br><br>

# %% [markdown]
# We can fill in the cell now.

# %%
# %%mlalpha features
# path: /content/datalab/tmp/ml/iris/data_train.csv
# headers: key,species,sepal_length,sepal_width,petal_length,petal_width
# target: species
# id: key

# %% [markdown]
# After running above, you should see a generated featureset class. We will make some changes on it for demo purposes: <br><br>
# class CsvFeatures -> class IrisFeatures <br>
# attrs = -> measurements = <br>
# features.numeric('sepal_length').identity() -> features.numeric('sepal_length').max_abs_scale(1) <br>
# features.numeric('petal_length').identity() -> features.numeric('petal_length').discretize(5) <br><br>
# ...and then run the cell.

# %%
import google.cloud.ml.features as features

class IrisFeatures(object):
  """This class is generated from command line:
        # %mlalpha features
        path: /content/datalab/tmp/ml/iris/data_train.csv
        headers: key,species,sepal_length,sepal_width,petal_length,petal_width
        target: species
        id: key
        Please modify it as appropriate!!!
  """
  csv_columns = ('key','species','sepal_length','sepal_width','petal_length','petal_width')
  species = features.target('species').discrete()
  key = features.key('key')
  measurements = [
      features.numeric('petal_width').identity(),
      features.numeric('sepal_length').max_abs_scale(1),
      features.numeric('petal_length').discretize(5),
      features.numeric('sepal_width').identity(),
  ]

# %% [markdown]
# ### Analyze
#
# Once we have the feature set class defined, we can use datalab.ml.DataSet class to analyze the data. Note that: <br>
# 1. The Iris data is tiny so it is good for analyzing and visualizing without sampling it. If you have a much larger dataset (>>1000 instances), we recommend using datalab.data.Csv.sample_to() method to sample the data to ~1000 instances first. <br>
# 2. Data visualizations created by 'analyze()' method are created out of preprocessed data. How the data is preprocessed is defined in the featureset class. For example, "features.numeric('petal_width').identity()" means using the raw value. "features.numeric('sepal_length').max_abs_scale(1)" means scale the data into [-1, 1] range. <br>

# %% [markdown]
# ### Define your DataSet.

# %%
# %%mlalpha dataset --name ds
# source:
#   train: /content/datalab/tmp/ml/iris/data_train.csv
#   eval: /content/datalab/tmp/ml/iris/data_eval.csv
# featureset: IrisFeatures

# %% [markdown]
# The above defines a datalab.ml.DataSet instance with name "ds" in python namespace. You can call ds.plot() function to plot some static graphs, or call ds.analyze() to plot interactive graphs.

# %%
ds.plot(names=['train'])

# %%
ds.plot(columns=['sepal_length'])

# %% [markdown]
# Analyze one column 'petal_width'. It plots one histogram and one scatter plot with target column. Since in featureset class we choose 'identity()' transform, the values will be used directly.
# The graphs plotted in "analyze()" are interactive.

# %%
ds.analyze(columns=['petal_width'])
# Out:
# <div id="7b4be10d-e1d8-4e4c-b9cf-e9cf6abef893" style="height: 500px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7b4be10d-e1d8-4e4c-b9cf-e9cf6abef893", [{"name": "train", "yaxis": "y1", "text": null, "xaxis": "x1", "xbins": {"start": 0.1, "end": 2.5, "size": 0.24}, "x": [0.2, 0.3, 0.2, 1.3, 1.4, 1.0, 0.2, 2.3, 1.5, 1.8, 2.3, 1.8, 2.0, 0.4, 0.3, 1.5, 1.9, 0.2, 1.9, 0.2, 1.2, 2.5, 2.3, 0.4, 0.1, 0.2, 1.9, 0.3, 2.0, 1.4, 0.4, 1.3, 2.4, 0.2, 1.5, 1.8, 0.5, 1.2, 1.0, 1.8, 0.2, 1.3, 1.0, 1.3, 1.3, 0.1, 0.1, 1.3, 1.6, 1.4, 2.3, 1.3, 1.6, 2.4, 0.4, 1.8, 1.4, 0.3, 1.4, 0.2, 1.5, 2.1, 0.2, 1.2, 1.4, 1.8, 1.5, 2.1, 0.4, 2.1, 1.5, 0.2, 1.3, 2.1, 1.5, 2.5, 2.0, 2.4, 0.2, 1.1, 0.2, 2.1, 1.6, 1.8, 2.3, 1.8, 1.0, 1.8, 1.8, 0.4, 0.2, 1.8, 2.2, 0.3, 2.3, 0.1, 1.5, 1.0, 0.3, 2.2, 2.0, 1.6, 1.2, 1.4, 1.8, 1.9, 0.3, 1.4, 2.2, 1.3, 0.2, 1.0, 0.2, 1.5, 0.2, 1.0, 2.3, 0.2, 0.4, 0.2], "type": "histogram"}, {"name": "eval", "yaxis": "y2", "text": null, "xaxis": "x2", "xbins": {"start": 0.1, "end": 2.5, "size": 0.24}, "x": [1.7, 1.3, 1.1, 0.1, 1.1, 0.2, 0.2, 1.5, 0.2, 2.5, 0.2, 1.2, 1.3, 0.2, 1.3, 0.6, 2.0, 0.2, 1.3, 2.0, 1.5, 0.2, 1.7, 1.5, 2.3, 0.1, 2.1, 1.9, 0.2, 0.2], "type": "histogram"}], {"yaxis1": {"domain": [0.0, 1.0], "anchor": "x1", "title": "count"}, "xaxis2": {"range": [0.1, 2.5], "title": "petal_width", "domain": [0.55, 1.0], "anchor": "y2"}, "xaxis1": {"range": [0.1, 2.5], "title": "petal_width", "domain": [0.0, 0.45], "anchor": "y1"}, "height": 500, "width": 1000, "yaxis2": {"domain": [0.0, 1.0], "anchor": "x2", "title": "count"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
# <div id="af781f64-17a1-49cc-a72f-ce754b46e30b" style="height: 500px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("af781f64-17a1-49cc-a72f-ce754b46e30b", [{"opacity": 0, "showlegend": false, "yaxis": "y1", "xaxis": "x1", "hoverinfo": "none", "y": ["Iris-setosa", "Iris-versicolor", "Iris-virginica"], "x": [0.1, 2.5, 2.5], "type": "scatter"}, {"name": "train", "yaxis": "y1", "text": ["x=0.2 y=Iris-setosa target=Iris-setosa", "x=0.3 y=Iris-setosa target=Iris-setosa", "x=0.2 y=Iris-setosa target=Iris-setosa", "x=1.3 y=Iris-versicolor target=Iris-versicolor", "x=1.4 y=Iris-versicolor target=Iris-versicolor", "x=1.0 y=Iris-versicolor target=Iris-versicolor", "x=0.2 y=Iris-setosa target=Iris-setosa", "x=2.3 y=Iris-virginica target=Iris-virginica", "x=1.5 y=Iris-versicolor target=Iris-versicolor", "x=1.8 y=Iris-versicolor target=Iris-versicolor", "x=2.3 y=Iris-virginica target=Iris-virginica", "x=1.8 y=Iris-virginica target=Iris-virginica", "x=2.0 y=Iris-virginica target=Iris-virginica", "x=0.4 y=Iris-setosa target=Iris-setosa", "x=0.3 y=Iris-setosa target=Iris-setosa", "x=1.5 y=Iris-versicolor target=Iris-versicolor", "x=1.9 y=Iris-virginica target=Iris-virginica", "x=0.2 y=Iris-setosa target=Iris-setosa", "x=1.9 y=Iris-virginica target=Iris-virginica", "x=0.2 y=Iris-setosa target=Iris-setosa", "x=1.2 y=Iris-versicolor target=Iris-versicolor", "x=2.5 y=Iris-virginica target=Iris-virginica", "x=2.3 y=Iris-virginica target=Iris-virginica", "x=0.4 y=Iris-setosa target=Iris-setosa", "x=0.1 y=Iris-setosa target=Iris-setosa", "x=0.2 y=Iris-setosa target=Iris-setosa", "x=1.9 y=Iris-virginica target=Iris-virginica", "x=0.3 y=Iris-setosa target=Iris-setosa", "x=2.0 y=Iris-virginica target=Iris-virginica", "x=1.4 y=Iris-versicolor target=Iris-versicolor", "x=0.4 y=Iris-setosa target=Iris-setosa", "x=1.3 y=Iris-versicolor target=Iris-versicolor", "x=2.4 y=Iris-virginica target=Iris-virginica", "x=0.2 y=Iris-setosa target=Iris-setosa", "x=1.5 y=Iris-virginica target=Iris-virginica", "x=1.8 y=Iris-virginica target=Iris-virginica", "x=0.5 y=Iris-setosa target=Iris-setosa", "x=1.2 y=Iris-versicolor target=Iris-versicolor", "x=1.0 y=Iris-versicolor target=Iris-versicolor", "x=1.8 y=Iris-virginica target=Iris-virginica", "x=0.2 y=Iris-setosa target=Iris-setosa", "x=1.3 y=Iris-versicolor target=Iris-versicolor", "x=1.0 y=Iris-versicolor target=Iris-versicolor", "x=1.3 y=Iris-versicolor target=Iris-versicolor", "x=1.3 y=Iris-versicolor target=Iris-versicolor", "x=0.1 y=Iris-setosa target=Iris-setosa", "x=0.1 y=Iris-setosa target=Iris-setosa", "x=1.3 y=Iris-versicolor target=Iris-versicolor", "x=1.6 y=Iris-versicolor target=Iris-versicolor", "x=1.4 y=Iris-versicolor target=Iris-versicolor", "x=2.3 y=Iris-virginica target=Iris-virginica", "x=1.3 y=Iris-versicolor target=Iris-versicolor", "x=1.6 y=Iris-virginica target=Iris-virginica", "x=2.4 y=Iris-virginica target=Iris-virginica", "x=0.4 y=Iris-setosa target=Iris-setosa", "x=1.8 y=Iris-virginica target=Iris-virginica", "x=1.4 y=Iris-versicolor target=Iris-versicolor", "x=0.3 y=Iris-setosa target=Iris-setosa", "x=1.4 y=Iris-versicolor target=Iris-versicolor", "x=0.2 y=Iris-setosa target=Iris-setosa", "x=1.5 y=Iris-versicolor target=Iris-versicolor", "x=2.1 y=Iris-virginica target=Iris-virginica", "x=0.2 y=Iris-setosa target=Iris-setosa", "x=1.2 y=Iris-versicolor target=Iris-versicolor", "x=1.4 y=Iris-virginica target=Iris-virginica", "x=1.8 y=Iris-virginica target=Iris-virginica", "x=1.5 y=Iris-versicolor target=Iris-versicolor", "x=2.1 y=Iris-virginica target=Iris-virginica", "x=0.4 y=Iris-setosa target=Iris-setosa", "x=2.1 y=Iris-virginica target=Iris-virginica", "x=1.5 y=Iris-versicolor target=Iris-versicolor", "x=0.2 y=Iris-setosa target=Iris-setosa", "x=1.3 y=Iris-versicolor target=Iris-versicolor", "x=2.1 y=Iris-virginica target=I ...

# %% [markdown]
# Analyze 'sepal_length' column. The values will be transformed first into [-1, 1] range.

# %%
ds.analyze(columns=['sepal_length'])
# Out:
# <div id="c09435ed-a9a2-40f6-b672-f1fb3311f766" style="height: 500px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c09435ed-a9a2-40f6-b672-f1fb3311f766", [{"name": "train", "yaxis": "y1", "text": null, "xaxis": "x1", "xbins": {"start": -1.0, "end": 1.0, "size": 0.2}, "x": [-0.8333333333333335, -0.5555555555555558, -0.9444444444444442, 0.11111111111111094, 0.27777777777777746, -0.05555555555555558, -0.5555555555555558, 0.33333333333333326, 0.4444444444444444, -0.11111111111111094, 0.3888888888888886, 0.11111111111111094, -0.277777777777778, -0.38888888888888873, -0.8333333333333335, 0.33333333333333326, 0.7222222222222223, -0.6666666666666664, 0.11111111111111094, -0.4999999999999999, -0.33333333333333337, 0.6111111111111112, 0.4444444444444444, -0.5555555555555558, -0.6666666666666664, -0.611111111111111, 0.16666666666666674, -0.7222222222222223, 1.0, 0.3888888888888886, -0.38888888888888873, -0.33333333333333337, 0.11111111111111094, -0.7222222222222223, -0.05555555555555558, 0.16666666666666674, -0.5555555555555558, -0.2222222222222221, -0.16666666666666674, -0.11111111111111094, -0.611111111111111, 0.05555555555555558, -0.2222222222222221, -2.220446049250313e-16, 0.16666666666666674, -0.6666666666666664, -0.6666666666666664, -0.277777777777778, -0.05555555555555558, 0.4999999999999998, 0.16666666666666674, -0.33333333333333337, 0.6111111111111112, -0.16666666666666674, -0.38888888888888873, 0.11111111111111094, -2.220446049250313e-16, -0.5555555555555558, 0.33333333333333326, -0.16666666666666674, 0.16666666666666674, 0.5555555555555551, -0.9444444444444442, -0.16666666666666674, -2.220446049250313e-16, -0.05555555555555558, -0.38888888888888873, 0.833333333333333, -0.611111111111111, 0.4444444444444444, -0.277777777777778, -0.7222222222222223, -0.2222222222222221, 0.3888888888888886, -0.11111111111111094, 0.33333333333333326, 0.2222222222222221, 0.33333333333333326, -0.33333333333333337, -0.33333333333333337, -0.611111111111111, 0.16666666666666674, 0.11111111111111094, -2.220446049250313e-16, 0.8888888888888888, 0.6111111111111112, -0.6666666666666664, 0.2222222222222221, 0.05555555555555558, -0.2222222222222221, -0.7777777777777777, 0.6666666666666665, 0.8888888888888888, -0.8888888888888888, 0.4444444444444444, -1.0, 0.11111111111111094, -0.611111111111111, -0.2222222222222221, 0.16666666666666674, -0.2222222222222221, -0.05555555555555558, -0.16666666666666674, -2.220446049250313e-16, 0.33333333333333326, -0.16666666666666674, -0.611111111111111, -0.4999999999999999, 0.2222222222222221, -0.277777777777778, -0.4999999999999999, -0.33333333333333337, -0.7222222222222223, -0.05555555555555558, -0.5555555555555558, -0.611111111111111, 0.05555555555555558, -0.8333333333333335, -0.5555555555555558, -0.7777777777777777], "type": "histogram"}, {"name": "eval", "yaxis": "y2", "text": null, "xaxis": "x2", "xbins": {"start": -1.0, "end": 1.0, "size": 0.2}, "x": [-0.6666666666666664, -0.2222222222222221, -0.5555555555555558, -0.7222222222222223, -0.277777777777778, -0.38888888888888873, -0.33333333333333337, 0.05555555555555558, -0.5555555555555558, 0.11111111111111094, -0.9444444444444442, -2.220446049250313e-16, -0.2222222222222221, -0.611111111111111, -0.277777777777778, -0.611111111111111, 0.8888888888888888, -0.8333333333333335, 0.27777777777777746, 0.2222222222222221, 0.2222222222222221, -0.44444444444444453, 0.33333333333333326, 0.11111111111111094, 0.8888888888888888, -0.4999999999999999, 0.33333333333333326, -0.16666666666666674, -0.38888888888888873, -0.611111111111111], "type": "histogram"}], {"yaxis1": {"domain": [0.0, 1.0], "anchor": "x1", "title": "count"}, "xaxis2": {"range": [-1.0, 1.0], "title": "sepal_length", "domain": [0.55, 1.0], "anchor": "y2"}, "xaxis1": {"range": [-1.0, 1.0], "title": "sepal_length", "domain": [0.0, 0.45], "anchor": "y1"}, ...
# <div id="2916609e-5ca3-4be2-8f46-de75fbc08abc" style="height: 500px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2916609e-5ca3-4be2-8f46-de75fbc08abc", [{"opacity": 0, "showlegend": false, "yaxis": "y1", "xaxis": "x1", "hoverinfo": "none", "y": ["Iris-setosa", "Iris-versicolor", "Iris-virginica"], "x": [-1.0, 1.0, 1.0], "type": "scatter"}, {"name": "train", "yaxis": "y1", "text": ["x=-0.833333333333 y=Iris-setosa target=Iris-setosa", "x=-0.555555555556 y=Iris-setosa target=Iris-setosa", "x=-0.944444444444 y=Iris-setosa target=Iris-setosa", "x=0.111111111111 y=Iris-versicolor target=Iris-versicolor", "x=0.277777777778 y=Iris-versicolor target=Iris-versicolor", "x=-0.0555555555556 y=Iris-versicolor target=Iris-versicolor", "x=-0.555555555556 y=Iris-setosa target=Iris-setosa", "x=0.333333333333 y=Iris-virginica target=Iris-virginica", "x=0.444444444444 y=Iris-versicolor target=Iris-versicolor", "x=-0.111111111111 y=Iris-versicolor target=Iris-versicolor", "x=0.388888888889 y=Iris-virginica target=Iris-virginica", "x=0.111111111111 y=Iris-virginica target=Iris-virginica", "x=-0.277777777778 y=Iris-virginica target=Iris-virginica", "x=-0.388888888889 y=Iris-setosa target=Iris-setosa", "x=-0.833333333333 y=Iris-setosa target=Iris-setosa", "x=0.333333333333 y=Iris-versicolor target=Iris-versicolor", "x=0.722222222222 y=Iris-virginica target=Iris-virginica", "x=-0.666666666667 y=Iris-setosa target=Iris-setosa", "x=0.111111111111 y=Iris-virginica target=Iris-virginica", "x=-0.5 y=Iris-setosa target=Iris-setosa", "x=-0.333333333333 y=Iris-versicolor target=Iris-versicolor", "x=0.611111111111 y=Iris-virginica target=Iris-virginica", "x=0.444444444444 y=Iris-virginica target=Iris-virginica", "x=-0.555555555556 y=Iris-setosa target=Iris-setosa", "x=-0.666666666667 y=Iris-setosa target=Iris-setosa", "x=-0.611111111111 y=Iris-setosa target=Iris-setosa", "x=0.166666666667 y=Iris-virginica target=Iris-virginica", "x=-0.722222222222 y=Iris-setosa target=Iris-setosa", "x=1.0 y=Iris-virginica target=Iris-virginica", "x=0.388888888889 y=Iris-versicolor target=Iris-versicolor", "x=-0.388888888889 y=Iris-setosa target=Iris-setosa", "x=-0.333333333333 y=Iris-versicolor target=Iris-versicolor", "x=0.111111111111 y=Iris-virginica target=Iris-virginica", "x=-0.722222222222 y=Iris-setosa target=Iris-setosa", "x=-0.0555555555556 y=Iris-virginica target=Iris-virginica", "x=0.166666666667 y=Iris-virginica target=Iris-virginica", "x=-0.555555555556 y=Iris-setosa target=Iris-setosa", "x=-0.222222222222 y=Iris-versicolor target=Iris-versicolor", "x=-0.166666666667 y=Iris-versicolor target=Iris-versicolor", "x=-0.111111111111 y=Iris-virginica target=Iris-virginica", "x=-0.611111111111 y=Iris-setosa target=Iris-setosa", "x=0.0555555555556 y=Iris-versicolor target=Iris-versicolor", "x=-0.222222222222 y=Iris-versicolor target=Iris-versicolor", "x=-2.22044604925e-16 y=Iris-versicolor target=Iris-versicolor", "x=0.166666666667 y=Iris-versicolor target=Iris-versicolor", "x=-0.666666666667 y=Iris-setosa target=Iris-setosa", "x=-0.666666666667 y=Iris-setosa target=Iris-setosa", "x=-0.277777777778 y=Iris-versicolor target=Iris-versicolor", "x=-0.0555555555556 y=Iris-versicolor target=Iris-versicolor", "x=0.5 y=Iris-versicolor target=Iris-versicolor", "x=0.166666666667 y=Iris-virginica target=Iris-virginica", "x=-0.333333333333 y=Iris-versicolor target=Iris-versicolor", "x=0.611111111111 y=Iris-virginica target=Iris-virginica", "x=-0.166666666667 y=Iris-virginica target=Iris-virginica", "x=-0.388888888889 y=Iris-setosa target=Iris-setosa", "x=0.111111111111 y=Iris-virginica target=Iris-virginica", "x=-2.22044604925e-16 y=Iris-versicolor target=Iris-versicolor", "x=-0.555555555556 y=Iris-setosa target=Iris-setosa", "x=0.333333333333 y=Iris-versicolor target=Iris-versicolor", "x=-0.166666666667 y=Iris-s ...

# %% [markdown]
# Analyze 'petal_length' column. The values will be transformed into 5 buckets first before visualization. Note that the histogram will be plotted with 5 buckets, as we specified in 'features.numeric('petal_length').discretize(5)'. Also, in the scatter plot since both x axis and y axis are discrete values, many points overlap.

# %%
ds.analyze(columns=['petal_length'])
# Out:
# <div id="1f983431-bd39-4c48-8a0d-992e86f0a1c6" style="height: 500px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1f983431-bd39-4c48-8a0d-992e86f0a1c6", [{"name": "train", "yaxis": "y1", "text": [0, 1, 2, 3, 4, 5, 6], "xaxis": "x1", "xbins": {"start": 0, "end": 4, "size": 1}, "x": [0, 0, 0, 2, 2, 2, 0, 3, 3, 3, 4, 3, 3, 0, 0, 3, 4, 0, 3, 0, 2, 4, 3, 0, 0, 0, 3, 0, 4, 3, 0, 2, 3, 0, 3, 3, 0, 2, 2, 3, 0, 2, 2, 2, 2, 0, 0, 2, 3, 3, 3, 2, 4, 3, 0, 3, 3, 0, 2, 0, 2, 4, 0, 2, 3, 3, 2, 4, 0, 3, 2, 0, 2, 3, 2, 3, 3, 3, 0, 2, 0, 3, 3, 3, 4, 4, 1, 3, 3, 0, 0, 4, 4, 0, 3, 0, 3, 1, 0, 3, 3, 2, 2, 3, 4, 3, 0, 2, 4, 2, 0, 2, 0, 2, 0, 2, 3, 0, 0, 0], "type": "histogram"}, {"name": "eval", "yaxis": "y2", "text": [0, 1, 2, 3, 4, 5, 6], "xaxis": "x2", "xbins": {"start": 0, "end": 4, "size": 1}, "x": [2, 2, 1, 0, 2, 0, 0, 2, 0, 4, 0, 3, 2, 0, 2, 0, 4, 0, 3, 3, 3, 0, 3, 3, 4, 0, 3, 3, 0, 0], "type": "histogram"}], {"yaxis1": {"domain": [0.0, 1.0], "anchor": "x1", "title": "count"}, "xaxis2": {"range": [0, 4], "title": "petal_length", "domain": [0.55, 1.0], "anchor": "y2"}, "xaxis1": {"range": [0, 4], "title": "petal_length", "domain": [0.0, 0.45], "anchor": "y1"}, "height": 500, "width": 1000, "yaxis2": {"domain": [0.0, 1.0], "anchor": "x2", "title": "count"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
# <div id="aeb2fec0-ab00-4a81-bb27-d3d8162125d3" style="height: 500px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aeb2fec0-ab00-4a81-bb27-d3d8162125d3", [{"opacity": 0, "showlegend": false, "yaxis": "y1", "xaxis": "x1", "hoverinfo": "none", "y": ["Iris-setosa", "Iris-versicolor", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica"], "x": [0, 1, 2, 3, 4, 5, 6], "type": "scatter"}, {"name": "train", "yaxis": "y1", "text": ["x=0 y=Iris-setosa target=Iris-setosa", "x=0 y=Iris-setosa target=Iris-setosa", "x=0 y=Iris-setosa target=Iris-setosa", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=0 y=Iris-setosa target=Iris-setosa", "x=3 y=Iris-virginica target=Iris-virginica", "x=3 y=Iris-versicolor target=Iris-versicolor", "x=3 y=Iris-versicolor target=Iris-versicolor", "x=4 y=Iris-virginica target=Iris-virginica", "x=3 y=Iris-virginica target=Iris-virginica", "x=3 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=0 y=Iris-setosa target=Iris-setosa", "x=3 y=Iris-versicolor target=Iris-versicolor", "x=4 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=3 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=4 y=Iris-virginica target=Iris-virginica", "x=3 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=0 y=Iris-setosa target=Iris-setosa", "x=0 y=Iris-setosa target=Iris-setosa", "x=3 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=4 y=Iris-virginica target=Iris-virginica", "x=3 y=Iris-versicolor target=Iris-versicolor", "x=0 y=Iris-setosa target=Iris-setosa", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=3 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=3 y=Iris-virginica target=Iris-virginica", "x=3 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=3 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=0 y=Iris-setosa target=Iris-setosa", "x=0 y=Iris-setosa target=Iris-setosa", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=3 y=Iris-versicolor target=Iris-versicolor", "x=3 y=Iris-versicolor target=Iris-versicolor", "x=3 y=Iris-virginica target=Iris-virginica", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=4 y=Iris-virginica target=Iris-virginica", "x=3 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=3 y=Iris-virginica target=Iris-virginica", "x=3 y=Iris-versicolor target=Iris-versicolor", "x=0 y=Iris-setosa target=Iris-setosa", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=0 y=Iris-setosa target=Iris-setosa", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=4 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=3 y=Iris-virginica target=Iris-virginica", "x=3 y=Iris-virginica target=Iris-virginica", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=4 y=Iris-virginica target=Iris-virginica", "x=0 y=Iris-setosa target=Iris-setosa", "x=3 y=Iris-virginica target=Iris-virginica", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=0 y=Iris-setosa target=Iris-setosa", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=3 y=Iris-virginica target=Iris-virginica", "x=2 y=Iris-versicolor target=Iris-versicolor", "x=3 y ...

# %% [markdown]
# We can also analyze two columns. It creates scatter plot with the two features, and color is used for target classes.

# %%
ds.analyze(columns=['petal_width', 'sepal_width'])
# Out:
# <div id="0d215125-3120-482f-a154-b1e1a09ce6aa" style="height: 500px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0d215125-3120-482f-a154-b1e1a09ce6aa", [{"opacity": 0, "showlegend": false, "yaxis": "y1", "xaxis": "x1", "hoverinfo": "none", "y": [2.0, 4.4], "x": [0.1, 2.5], "type": "scatter"}, {"name": "train", "yaxis": "y1", "text": ["x=0.2 y=3.1 target=Iris-setosa", "x=0.3 y=3.8 target=Iris-setosa", "x=0.2 y=3.2 target=Iris-setosa", "x=1.3 y=2.3 target=Iris-versicolor", "x=1.4 y=3.0 target=Iris-versicolor", "x=1.0 y=2.2 target=Iris-versicolor", "x=0.2 y=3.8 target=Iris-setosa", "x=2.3 y=3.0 target=Iris-virginica", "x=1.5 y=3.1 target=Iris-versicolor", "x=1.8 y=3.2 target=Iris-versicolor", "x=2.3 y=3.2 target=Iris-virginica", "x=1.8 y=2.7 target=Iris-virginica", "x=2.0 y=2.8 target=Iris-virginica", "x=0.4 y=3.9 target=Iris-setosa", "x=0.3 y=3.4 target=Iris-setosa", "x=1.5 y=3.1 target=Iris-versicolor", "x=1.9 y=2.8 target=Iris-virginica", "x=0.2 y=3.0 target=Iris-setosa", "x=1.9 y=2.5 target=Iris-virginica", "x=0.2 y=3.4 target=Iris-setosa", "x=1.2 y=2.6 target=Iris-versicolor", "x=2.5 y=3.6 target=Iris-virginica", "x=2.3 y=3.2 target=Iris-virginica", "x=0.4 y=3.8 target=Iris-setosa", "x=0.1 y=3.1 target=Iris-setosa", "x=0.2 y=3.2 target=Iris-setosa", "x=1.9 y=2.7 target=Iris-virginica", "x=0.3 y=3.0 target=Iris-setosa", "x=2.0 y=3.8 target=Iris-virginica", "x=1.4 y=2.8 target=Iris-versicolor", "x=0.4 y=3.9 target=Iris-setosa", "x=1.3 y=2.5 target=Iris-versicolor", "x=2.4 y=3.4 target=Iris-virginica", "x=0.2 y=3.1 target=Iris-setosa", "x=1.5 y=2.2 target=Iris-virginica", "x=1.8 y=3.1 target=Iris-virginica", "x=0.5 y=3.3 target=Iris-setosa", "x=1.2 y=3.0 target=Iris-versicolor", "x=1.0 y=2.7 target=Iris-versicolor", "x=1.8 y=3.0 target=Iris-virginica", "x=0.2 y=3.0 target=Iris-setosa", "x=1.3 y=2.9 target=Iris-versicolor", "x=1.0 y=2.6 target=Iris-versicolor", "x=1.3 y=2.8 target=Iris-versicolor", "x=1.3 y=2.9 target=Iris-versicolor", "x=0.1 y=3.1 target=Iris-setosa", "x=0.1 y=3.1 target=Iris-setosa", "x=1.3 y=3.0 target=Iris-versicolor", "x=1.6 y=2.7 target=Iris-versicolor", "x=1.4 y=3.2 target=Iris-versicolor", "x=2.3 y=3.2 target=Iris-virginica", "x=1.3 y=2.3 target=Iris-versicolor", "x=1.6 y=3.0 target=Iris-virginica", "x=2.4 y=2.8 target=Iris-virginica", "x=0.4 y=3.4 target=Iris-setosa", "x=1.8 y=2.9 target=Iris-virginica", "x=1.4 y=2.9 target=Iris-versicolor", "x=0.3 y=3.5 target=Iris-setosa", "x=1.4 y=3.1 target=Iris-versicolor", "x=0.2 y=4.0 target=Iris-setosa", "x=1.5 y=3.2 target=Iris-versicolor", "x=2.1 y=3.0 target=Iris-virginica", "x=0.2 y=2.9 target=Iris-setosa", "x=1.2 y=2.7 target=Iris-versicolor", "x=1.4 y=2.6 target=Iris-virginica", "x=1.8 y=3.0 target=Iris-virginica", "x=1.5 y=3.0 target=Iris-versicolor", "x=2.1 y=3.0 target=Iris-virginica", "x=0.4 y=3.4 target=Iris-setosa", "x=2.1 y=3.1 target=Iris-virginica", "x=1.5 y=3.0 target=Iris-versicolor", "x=0.2 y=3.4 target=Iris-setosa", "x=1.3 y=2.8 target=Iris-versicolor", "x=2.1 y=3.0 target=Iris-virginica", "x=1.5 y=3.0 target=Iris-versicolor", "x=2.5 y=3.3 target=Iris-virginica", "x=2.0 y=3.2 target=Iris-virginica", "x=2.4 y=3.1 target=Iris-virginica", "x=0.2 y=4.2 target=Iris-setosa", "x=1.1 y=2.4 target=Iris-versicolor", "x=0.2 y=3.4 target=Iris-setosa", "x=2.1 y=2.8 target=Iris-virginica", "x=1.6 y=3.3 target=Iris-versicolor", "x=1.8 y=3.0 target=Iris-virginica", "x=2.3 y=2.6 target=Iris-virginica", "x=1.8 y=3.2 target=Iris-virginica", "x=1.0 y=2.4 target=Iris-versicolor", "x=1.8 y=3.0 target=Iris-virginica", "x=1.8 y=2.8 target=Iris-virginica", "x=0.4 y=4.4 target=Iris-setosa", "x=0.2 y=3.2 target=Iris-setosa", "x=1.8 y=2.9 target=Iris-virginica", "x=2.2 y=3.8 target=Iris-virginica", "x=0.3 y=2.3 target=Iris-setosa", "x=2.3 y=3.1 target=Iris-virginica", "x=0.1 y=3.0 target=Iris-setosa", ...

# %% [markdown]
# Analyze three columns. You can zoom-in/out or rotate!

# %%
ds.analyze(columns=['sepal_width', 'petal_length', 'petal_width'])
# Out:
# <div id="346bda0c-9ac8-484b-b708-f9cfcec87616" style="height: 500px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("346bda0c-9ac8-484b-b708-f9cfcec87616", [{"name": "train", "text": ["x=3.1 y=0 z=0.2, target=Iris-setosa", "x=3.8 y=0 z=0.3, target=Iris-setosa", "x=3.2 y=0 z=0.2, target=Iris-setosa", "x=2.3 y=2 z=1.3, target=Iris-versicolor", "x=3.0 y=2 z=1.4, target=Iris-versicolor", "x=2.2 y=2 z=1.0, target=Iris-versicolor", "x=3.8 y=0 z=0.2, target=Iris-setosa", "x=3.0 y=3 z=2.3, target=Iris-virginica", "x=3.1 y=3 z=1.5, target=Iris-versicolor", "x=3.2 y=3 z=1.8, target=Iris-versicolor", "x=3.2 y=4 z=2.3, target=Iris-virginica", "x=2.7 y=3 z=1.8, target=Iris-virginica", "x=2.8 y=3 z=2.0, target=Iris-virginica", "x=3.9 y=0 z=0.4, target=Iris-setosa", "x=3.4 y=0 z=0.3, target=Iris-setosa", "x=3.1 y=3 z=1.5, target=Iris-versicolor", "x=2.8 y=4 z=1.9, target=Iris-virginica", "x=3.0 y=0 z=0.2, target=Iris-setosa", "x=2.5 y=3 z=1.9, target=Iris-virginica", "x=3.4 y=0 z=0.2, target=Iris-setosa", "x=2.6 y=2 z=1.2, target=Iris-versicolor", "x=3.6 y=4 z=2.5, target=Iris-virginica", "x=3.2 y=3 z=2.3, target=Iris-virginica", "x=3.8 y=0 z=0.4, target=Iris-setosa", "x=3.1 y=0 z=0.1, target=Iris-setosa", "x=3.2 y=0 z=0.2, target=Iris-setosa", "x=2.7 y=3 z=1.9, target=Iris-virginica", "x=3.0 y=0 z=0.3, target=Iris-setosa", "x=3.8 y=4 z=2.0, target=Iris-virginica", "x=2.8 y=3 z=1.4, target=Iris-versicolor", "x=3.9 y=0 z=0.4, target=Iris-setosa", "x=2.5 y=2 z=1.3, target=Iris-versicolor", "x=3.4 y=3 z=2.4, target=Iris-virginica", "x=3.1 y=0 z=0.2, target=Iris-setosa", "x=2.2 y=3 z=1.5, target=Iris-virginica", "x=3.1 y=3 z=1.8, target=Iris-virginica", "x=3.3 y=0 z=0.5, target=Iris-setosa", "x=3.0 y=2 z=1.2, target=Iris-versicolor", "x=2.7 y=2 z=1.0, target=Iris-versicolor", "x=3.0 y=3 z=1.8, target=Iris-virginica", "x=3.0 y=0 z=0.2, target=Iris-setosa", "x=2.9 y=2 z=1.3, target=Iris-versicolor", "x=2.6 y=2 z=1.0, target=Iris-versicolor", "x=2.8 y=2 z=1.3, target=Iris-versicolor", "x=2.9 y=2 z=1.3, target=Iris-versicolor", "x=3.1 y=0 z=0.1, target=Iris-setosa", "x=3.1 y=0 z=0.1, target=Iris-setosa", "x=3.0 y=2 z=1.3, target=Iris-versicolor", "x=2.7 y=3 z=1.6, target=Iris-versicolor", "x=3.2 y=3 z=1.4, target=Iris-versicolor", "x=3.2 y=3 z=2.3, target=Iris-virginica", "x=2.3 y=2 z=1.3, target=Iris-versicolor", "x=3.0 y=4 z=1.6, target=Iris-virginica", "x=2.8 y=3 z=2.4, target=Iris-virginica", "x=3.4 y=0 z=0.4, target=Iris-setosa", "x=2.9 y=3 z=1.8, target=Iris-virginica", "x=2.9 y=3 z=1.4, target=Iris-versicolor", "x=3.5 y=0 z=0.3, target=Iris-setosa", "x=3.1 y=2 z=1.4, target=Iris-versicolor", "x=4.0 y=0 z=0.2, target=Iris-setosa", "x=3.2 y=2 z=1.5, target=Iris-versicolor", "x=3.0 y=4 z=2.1, target=Iris-virginica", "x=2.9 y=0 z=0.2, target=Iris-setosa", "x=2.7 y=2 z=1.2, target=Iris-versicolor", "x=2.6 y=3 z=1.4, target=Iris-virginica", "x=3.0 y=3 z=1.8, target=Iris-virginica", "x=3.0 y=2 z=1.5, target=Iris-versicolor", "x=3.0 y=4 z=2.1, target=Iris-virginica", "x=3.4 y=0 z=0.4, target=Iris-setosa", "x=3.1 y=3 z=2.1, target=Iris-virginica", "x=3.0 y=2 z=1.5, target=Iris-versicolor", "x=3.4 y=0 z=0.2, target=Iris-setosa", "x=2.8 y=2 z=1.3, target=Iris-versicolor", "x=3.0 y=3 z=2.1, target=Iris-virginica", "x=3.0 y=2 z=1.5, target=Iris-versicolor", "x=3.3 y=3 z=2.5, target=Iris-virginica", "x=3.2 y=3 z=2.0, target=Iris-virginica", "x=3.1 y=3 z=2.4, target=Iris-virginica", "x=4.2 y=0 z=0.2, target=Iris-setosa", "x=2.4 y=2 z=1.1, target=Iris-versicolor", "x=3.4 y=0 z=0.2, target=Iris-setosa", "x=2.8 y=3 z=2.1, target=Iris-virginica", "x=3.3 y=3 z=1.6, target=Iris-versicolor", "x=3.0 y=3 z=1.8, target=Iris-virginica", "x=2.6 y=4 z=2.3, target=Iris-virginica", "x=3.2 y=4 z=1.8, target=Iris-virginica", "x=2.4 y=1 z=1.0, target=Iris-versicolor", "x=3.0 y=3 z=1.8, target=Iris-virginica", ...

# %% [markdown]
# profile() shows you a profile on raw data.

# %%
ds.profile(names=['train'])
# Out:
# <br/><br/><p style="text-align:center"><font size="6"><b>train</b></font></p><br/><br/><meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats tr:hover{
#                 text-decoration: underline;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>120 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>5.7 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>48.6 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><code>petal_width</code> is highly correlated with <code>petal_length</code> (ρ = 0.95992) <span class="label label-primary">Rejected</span></l> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4">key<br/>
#             <small>Categorical, Unique</small>
#         </p>
#     </div><div class="col-md-3 collapse in" id="minivalues8639268678046072022"><table border="1" class="dataframe example_values">
#   <thead>
#     <tr style="text-align: right;">
#       <th>First 3 values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>137</td>
#     </tr>
#     <tr>
#       <td>98</td>
#     </tr>
#     <tr>
#       <td>63</td>
#     </tr>
#   </tbody>
# </table></div>
# <div class="col-md-6 collapse in" id="minivalues8639268678046072022"><table border="1" class="dataframe example_values">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Last 3 values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>133</td>
#     </tr>
#   </tbody>
# </table></div>
# <div class="col-md-12 text-right">
#     <a role="button" data-toggle="collapse" data-target="#values8639268678046072022,#minivalues8639268678046072022" aria-expanded="false"
#        aria-controls="collapseExample">
#         Toggle details
#     </a>
# </div>
# <div class="col-md-12 collapse" id="values8639268678046072022">
#     <p class="
