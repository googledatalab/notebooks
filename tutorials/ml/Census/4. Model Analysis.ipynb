# %% [markdown]
# ## Model Analysis
#
# Analyze the model by looking at the summary events the training program outputs. Let's look at the events the local run generated in previous notebook, but events generated by cloud run in GCS works too.<br>
#
# First list events.

# %%
# %ml summary --dir /content/datalab/tmp/ml/census/model/summaries /content/datalab/tmp/ml/census/model/eval
# Out:
# <ul><li>loss</li><li>queue/input_producer/fraction_of_32_full</li><li>queue/batch/fifo_queue/fraction_of_192_full</li><li>error</li></ul>

# %% [markdown]
# Plot events.

# %%
# %ml summary --dir /content/datalab/tmp/ml/census/model/summaries  /content/datalab/tmp/ml/census/model/eval  --name loss error --step
# Out:
# <div id="7d630c6c-a752-4817-8c81-42e85dbd09b8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7d630c6c-a752-4817-8c81-42e85dbd09b8", [{"y": [], "x": [], "type": "scatter", "name": "loss-/content/datalab/tmp/ml/census/model/eval"}, {"y": [74732.2578125, 55891.4296875, 49201.953125, 48870.9609375], "x": [637, 1242, 1856, 2003], "type": "scatter", "name": "error-/content/datalab/tmp/ml/census/model/eval"}, {"y": [82633.484375, 70975.5625, 59355.828125, 56506.140625, 47808.9140625], "x": [200, 600, 800, 1200, 1600], "type": "scatter", "name": "loss-/content/datalab/tmp/ml/census/model/summaries"}, {"y": [], "x": [], "type": "scatter", "name": "error-/content/datalab/tmp/ml/census/model/summaries"}], {"title": "loss,error", "xaxis": {"title": "step"}, "yaxis": {"title": "loss,error"}}, {"linkText": "Ex
# ...

# %% [markdown]
# Note that you can plot events in the same graph from multiple directories (--dir support multiple values, just like --name). This is useful if you want to compare two model's training progress. Below we plot events under 2 different model dirs: /content/datalab/tmp/ml/census/model/summaries and /content/datalab/tmp/ml/census/largermodel/summaries.<br>

# %%
# %ml summary --dir /content/datalab/tmp/ml/census/*/summaries /content/datalab/tmp/ml/census/*/eval --name loss error --step
# Out:
# <div id="7051fe0b-118b-45ba-b23d-e73856e8446f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7051fe0b-118b-45ba-b23d-e73856e8446f", [{"y": [], "x": [], "type": "scatter", "name": "loss-/content/datalab/tmp/ml/census/model/eval"}, {"y": [74732.2578125, 55891.4296875, 49201.953125, 48870.9609375], "x": [637, 1242, 1856, 2003], "type": "scatter", "name": "error-/content/datalab/tmp/ml/census/model/eval"}, {"y": [82250.2734375, 87317.140625, 52490.09375, 49775.64453125, 47878.96875, 53958.8046875, 57593.34375, 52071.91796875], "x": [0, 200, 400, 600, 1000, 1400, 1800, 2000], "type": "scatter", "name": "loss-/content/datalab/tmp/ml/census/largermodel/summaries"}, {"y": [], "x": [], "type": "scatter", "name": "error-/content/datalab/tmp/ml/census/largermodel/summaries"}, {"y": [82633.484375, 70975.5625
# ...
