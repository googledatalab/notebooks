# %% [markdown]
# ## Model Analysis
#
# Analyze the model by looking at the summary events the training program outputs. Let's look at the events the two local run generates in previous notebook, but events generated by cloud run works too.

# %% [markdown]
# Using "%mlalpha summary" command to view events. First list events in a given dir.

# %%
# %mlalpha summary --dir /content/datalab/tmp/ml/iris/model/
# Out:
# <ul><li>loss</li><li>dnn/logits:activation</li><li>queue/batch/fifo_queue/fraction_of_450_full</li><li>dnn/hiddenlayer_0:fraction_of_zero_values</li><li>queue/input_producer/fraction_of_32_full</li><li>dnn/logits:fraction_of_zero_values</li><li>centered_bias 2</li><li>centered_bias 1</li><li>dnn/hiddenlayer_0:activation</li><li>centered_bias 0</li><li>global_step/sec</li></ul>

# %% [markdown]
# Plot loss graphs one based on time and one based on time.

# %%
# %mlalpha summary --dir /content/datalab/tmp/ml/iris/model --name loss --time
# Out:
# <div id="6cdd4f1c-526f-4d5e-96fc-10e331ec474e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6cdd4f1c-526f-4d5e-96fc-10e331ec474e", [{"y": [1.060494303703308, 0.668447732925415, 0.4114142954349518, 0.29840993881225586, 0.2393368035554886, 0.1956019103527069, 0.15994930267333984, 0.13227486610412598, 0.11138330399990082, 0.09616685658693314, 0.08479607850313187, 0.07608231157064438, 0.0692167729139328, 0.06358640640974045, 0.05905989184975624, 0.05520740523934364, 0.051880281418561935, 0.04900059476494789, 0.0464668832719326, 0.044246308505535126], "x": [0.830323, 1.815914, 2.008138, 2.205504, 2.376692, 2.547398, 2.701362, 2.874895, 3.033628, 3.19115, 3.375139, 3.559624, 3.752213, 3.906423, 4.079539, 4.25989, 4.452994, 4.624784, 4.807385, 5.004439], "type": "scatter", "name": "loss-/content/datalab/tmp/ml/iris/model"}], {"title": "loss", "xaxis": {"title": "seconds"}, "yaxis": {"title": "loss"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# Plot loss graph with steps, and also compare two runs.

# %%
# %mlalpha summary --dir /content/datalab/tmp/ml/iris/model  /content/datalab/tmp/ml/iris/model_lr --name loss --step
# Out:
# <div id="680d617f-bbaa-43a6-b7f8-5c811252044a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("680d617f-bbaa-43a6-b7f8-5c811252044a", [{"y": [1.083981990814209, 0.8058592081069946, 0.5587551593780518, 0.4021129906177521, 0.3153078854084015, 0.26044967770576477, 0.2192193865776062, 0.18527910113334656, 0.1567801535129547, 0.13439102470874786, 0.11658405512571335, 0.10237810015678406, 0.09099557250738144, 0.08193998783826828, 0.07456841319799423, 0.06857550889253616, 0.06357663869857788, 0.05937882140278816, 0.05578005313873291, 0.05265900865197182, 0.0499531514942646, 0.04756743833422661, 0.04544416442513466, 0.043553706258535385, 0.04185473918914795, 0.04032474756240845, 0.03893432766199112, 0.03766985237598419, 0.0365169383585453, 0.035459358245134354, 0.03448818251490593], "x": [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000], "type": "scatter", "name": "loss-/content/datalab/tmp/ml/iris/model_lr"}, {"y": [1.060494303703308, 0.668447732925415, 0.4114142954349518, 0.29840993881225586, 0.2393368035554886, 0.1956019103527069, 0.15994930267333984, 0.13227486610412598, 0.11138330399990082, 0.09616685658693314, 0.08479607850313187, 0.07608231157064438, 0.0692167729139328, 0.06358640640974045, 0.05905989184975624, 0.05520740523934364, 0.051880281418561935, 0.04900059476494789, 0.0464668832719326, 0.044246308505535126], "x": [1, 101, 201, 301, 401, 501, 601, 701, 801, 901, 1001, 1101, 1201, 1301, 1401, 1501, 1601, 1701, 1801, 1901], "type": "scatter", "name": "loss-/content/datalab/tmp/ml/iris/model"}], {"title": "loss", "xaxis": {"title": "step"}, "yaxis": {"title": "loss"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# Multiple events can be plotted in the same graph too.

# %%
# %mlalpha summary --dir /content/datalab/tmp/ml/iris/model  /content/datalab/tmp/ml/iris/model_lr --name loss dnn/hiddenlayer_0:fraction_of_zero_values --step
# Out:
# <div id="a182077f-37b3-4705-b101-8b13aba03735" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a182077f-37b3-4705-b101-8b13aba03735", [{"y": [1.083981990814209, 0.8058592081069946, 0.5587551593780518, 0.4021129906177521, 0.3153078854084015, 0.26044967770576477, 0.2192193865776062, 0.18527910113334656, 0.1567801535129547, 0.13439102470874786, 0.11658405512571335, 0.10237810015678406, 0.09099557250738144, 0.08193998783826828, 0.07456841319799423, 0.06857550889253616, 0.06357663869857788, 0.05937882140278816, 0.05578005313873291, 0.05265900865197182, 0.0499531514942646, 0.04756743833422661, 0.04544416442513466, 0.043553706258535385, 0.04185473918914795, 0.04032474756240845, 0.03893432766199112, 0.03766985237598419, 0.0365169383585453, 0.035459358245134354, 0.03448818251490593], "x": [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000], "type": "scatter", "name": "loss-/content/datalab/tmp/ml/iris/model_lr"}, {"y": [0.47333332896232605, 0.4566666781902313, 0.4266666769981384, 0.3766666650772095, 0.3466666638851166, 0.33666667342185974, 0.3233333230018616, 0.3100000023841858, 0.3100000023841858, 0.3033333420753479, 0.30666667222976685, 0.30666667222976685, 0.30666667222976685, 0.3033333420753479, 0.3033333420753479, 0.30000001192092896, 0.30000001192092896, 0.30000001192092896, 0.30000001192092896, 0.3033333420753479, 0.3033333420753479, 0.3033333420753479, 0.3033333420753479, 0.30666667222976685, 0.30666667222976685, 0.3100000023841858, 0.3100000023841858, 0.3100000023841858, 0.30666667222976685, 0.30666667222976685, 0.30666667222976685], "x": [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000], "type": "scatter", "name": "dnn/hiddenlayer_0:fraction_of_zero_values-/content/datalab/tmp/ml/iris/model_lr"}, {"y": [1.060494303703308, 0.668447732925415, 0.4114142954349518, 0.29840993881225586, 0.2393368035554886, 0.1956019103527069, 0.15994930267333984, 0.13227486610412598, 0.11138330399990082, 0.09616685658693314, 0.08479607850313187, 0.07608231157064438, 0.0692167729139328, 0.06358640640974045, 0.05905989184975624, 0.05520740523934364, 0.051880281418561935, 0.04900059476494789, 0.0464668832719326, 0.044246308505535126], "x": [1, 101, 201, 301, 401, 501, 601, 701, 801, 901, 1001, 1101, 1201, 1301, 1401, 1501, 1601, 1701, 1801, 1901], "type": "scatter", "name": "loss-/content/datalab/tmp/ml/iris/model"}, {"y": [0.5016666650772095, 0.49000000953674316, 0.4933333396911621, 0.46166667342185974, 0.4233333468437195, 0.41333332657814026, 0.4116666615009308, 0.40833333134651184, 0.40666666626930237, 0.40833333134651184, 0.4099999964237213, 0.4116666615009308, 0.41333332657814026, 0.41499999165534973, 0.41499999165534973, 0.4183333218097687, 0.41999998688697815, 0.4216666519641876, 0.4216666519641876, 0.42500001192092896], "x": [1, 101, 201, 301, 401, 501, 601, 701, 801, 901, 1001, 1101, 1201, 1301, 1401, 1501, 1601, 1701, 1801, 1901], "type": "scatter", "name": "dnn/hiddenlayer_0:fraction_of_zero_values-/content/datalab/tmp/ml/iris/model"}], {"title": "loss,dnn/hiddenlayer_0:fraction_of_zero_values", "xaxis": {"title": "step"}, "yaxis": {"title": "loss,dnn/hiddenlayer_0:fraction_of_zero_values"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# Accuracy is boring (only one point per run) since we do it only once at the end of the training.

# %%
# %mlalpha summary --dir /content/datalab/tmp/ml/iris/*/eval  --name accuracy --step
# Out:
# <div id="4048ef1b-dd32-4130-8884-385c4a76cbe8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4048ef1b-dd32-4130-8884-385c4a76cbe8", [{"y": [0.4000000059604645, 0.8999999761581421], "x": [1, 3001], "type": "scatter", "name": "accuracy-/content/datalab/tmp/ml/iris/model_lr/eval"}, {"y": [0.23333333432674408, 0.8999999761581421], "x": [1, 2000], "type": "scatter", "name": "accuracy-/content/datalab/tmp/ml/iris/model/eval"}], {"title": "accuracy", "xaxis": {"title": "step"}, "yaxis": {"title": "accuracy"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# Note that the summary dir can be GCS path too.
