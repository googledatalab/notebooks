# %% [markdown]
# ## Model Analysis
#
# Analyze the model by looking at the summary events the training program outputs. Let's look at the events the two local run generates in previous notebook, but events generated by cloud run works too.

# %% [markdown]
# Using "%ml summary" command to view events. First list events in a given dir.

# %%
# %ml summary --dir /content/datalab/ml/iris/model3000/summaries
# Out:
# <ul><li>queue/batch/fifo_queue/fraction_of_48_full</li><li>queue/input_producer/fraction_of_32_full</li><li>loss</li></ul>

# %% [markdown]
# Plot loss graphs one based on time and one based on steps.

# %%
# %ml summary --dir /content/datalab/ml/iris/model3000/summaries --name loss
# Out:
# <div id="4b8a9812-d5bd-4f5f-b71d-a8c8fdd06140" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4b8a9812-d5bd-4f5f-b71d-a8c8fdd06140", [{"y": [0.47673559188842773, 0.06831399351358414, 0.04641636833548546, 0.016878226771950722, 0.003172262106090784, 0.022619860246777534, 0.034468866884708405, 0.10841257870197296, 0.006681996863335371, 0.03318267688155174, 0.014509553089737892, 0.0444960743188858, 0.04066542163491249, 0.04403013736009598, 0.10255947709083557], "x": [1.229944, 3.649404, 6.851954, 8.063251, 9.267812, 10.589493, 11.796069, 12.421124, 13.042274, 14.250774, 14.84834, 16.056652, 17.892482, 18.479436, 19.691724], "type": "scatter", "name": "loss-/content/datalab/ml/iris/model3000/summaries"}], {"title": "loss", "xaxis": {"title": "seconds"}, "yaxis": {"title": "loss"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
# <div id="d6c9f180-e863-47c7-8082-bd03dbb7b1a5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d6c9f180-e863-47c7-8082-bd03dbb7b1a5", [{"y": [0.47673559188842773, 0.06831399351358414, 0.04641636833548546, 0.016878226771950722, 0.003172262106090784, 0.022619860246777534, 0.034468866884708405, 0.10841257870197296, 0.006681996863335371, 0.03318267688155174, 0.014509553089737892, 0.0444960743188858, 0.04066542163491249, 0.04403013736009598, 0.10255947709083557], "x": [0, 400, 900, 1100, 1300, 1500, 1700, 1800, 1900, 2100, 2200, 2400, 2700, 2800, 3000], "type": "scatter", "name": "loss-/content/datalab/ml/iris/model3000/summaries"}], {"title": "loss", "xaxis": {"title": "step"}, "yaxis": {"title": "loss"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# Plot loss graph with only steps (no time based graph), and also compare two runs.

# %%
# %ml summary --dir /content/datalab/ml/iris/model3000/summaries  /content/datalab/ml/iris/model/summaries --name loss --step
# Out:
# <div id="7a84b5c7-b459-4164-b55f-cbfa20f95e3c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7a84b5c7-b459-4164-b55f-cbfa20f95e3c", [{"y": [0.47673559188842773, 0.06831399351358414, 0.04641636833548546, 0.016878226771950722, 0.003172262106090784, 0.022619860246777534, 0.034468866884708405, 0.10841257870197296, 0.006681996863335371, 0.03318267688155174, 0.014509553089737892, 0.0444960743188858, 0.04066542163491249, 0.04403013736009598, 0.10255947709083557], "x": [0, 400, 900, 1100, 1300, 1500, 1700, 1800, 1900, 2100, 2200, 2400, 2700, 2800, 3000], "type": "scatter", "name": "loss-/content/datalab/ml/iris/model3000/summaries"}, {"y": [0.8270570039749146, 0.13367801904678345, 0.139467254281044, 0.08251403272151947, 0.10119126737117767, 0.060396190732717514, 0.015078587457537651, 0.10270144790410995, 0.0055976081639528275, 0.10237866640090942, 0.05060875043272972, 0.0162440724670887, 0.056442342698574066, 0.021534811705350876, 0.023228511214256287, 0.007988154888153076, 0.017206590622663498, 0.0427732989192009, 0.037215255200862885, 0.04483385384082794, 0.03670867905020714], "x": [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000], "type": "scatter", "name": "loss-/content/datalab/ml/iris/model/summaries"}], {"title": "loss", "xaxis": {"title": "step"}, "yaxis": {"title": "loss"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# Multiple events can be plotted in the same graph too.

# %%
# %ml summary --dir /content/datalab/ml/iris/model3000/summaries  /content/datalab/ml/iris/model/summaries --name loss queue/batch/fifo_queue/fraction_of_48_full --step
# Out:
# <div id="dec8907a-ca6d-43e2-8256-8483a72f1f88" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("dec8907a-ca6d-43e2-8256-8483a72f1f88", [{"y": [0.47673559188842773, 0.06831399351358414, 0.04641636833548546, 0.016878226771950722, 0.003172262106090784, 0.022619860246777534, 0.034468866884708405, 0.10841257870197296, 0.006681996863335371, 0.03318267688155174, 0.014509553089737892, 0.0444960743188858, 0.04066542163491249, 0.04403013736009598, 0.10255947709083557], "x": [0, 400, 900, 1100, 1300, 1500, 1700, 1800, 1900, 2100, 2200, 2400, 2700, 2800, 3000], "type": "scatter", "name": "loss-/content/datalab/ml/iris/model3000/summaries"}, {"y": [0.02083333395421505, 0.0625, 0.0416666679084301, 0.0625, 0.0416666679084301, 0.0416666679084301, 0.0625, 0.0625, 0.0625, 0.0416666679084301, 0.0625, 0.0416666679084301, 0.0625, 0.0625, 0.0833333358168602], "x": [0, 400, 900, 1100, 1300, 1500, 1700, 1800, 1900, 2100, 2200, 2400, 2700, 2800, 3000], "type": "scatter", "name": "queue/batch/fifo_queue/fraction_of_48_full-/content/datalab/ml/iris/model3000/summaries"}, {"y": [0.8270570039749146, 0.13367801904678345, 0.139467254281044, 0.08251403272151947, 0.10119126737117767, 0.060396190732717514, 0.015078587457537651, 0.10270144790410995, 0.0055976081639528275, 0.10237866640090942, 0.05060875043272972, 0.0162440724670887, 0.056442342698574066, 0.021534811705350876, 0.023228511214256287, 0.007988154888153076, 0.017206590622663498, 0.0427732989192009, 0.037215255200862885, 0.04483385384082794, 0.03670867905020714], "x": [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000], "type": "scatter", "name": "loss-/content/datalab/ml/iris/model/summaries"}, {"y": [0.2291666716337204, 0.0625, 0.0833333358168602, 0.0625, 0.0625, 0.0833333358168602, 0.0625, 0.1041666716337204, 0.0833333358168602, 0.0625, 0.0833333358168602, 0.0625, 0.0625, 0.0833333358168602, 0.0625, 0.0625, 0.0833333358168602, 0.0416666679084301, 0.0625, 0.0625, 0.0833333358168602], "x": [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000], "type": "scatter", "name": "queue/batch/fifo_queue/fraction_of_48_full-/content/datalab/ml/iris/model/summaries"}], {"title": "loss,queue/batch/fifo_queue/fraction_of_48_full", "xaxis": {"title": "step"}, "yaxis": {"title": "loss,queue/batch/fifo_queue/fraction_of_48_full"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# Note that the summary dir can be GCS path too.
